# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.8-cp313-cp313-macosx_10_13_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-macosx_10_13_x86_64.whl.metadata (6.2 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.2.2-cp313-cp313-macosx_10_13_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/willgunter/coding/writing-observer/myenv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/willgunter/coding/writing-observer/myenv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/willgunter/coding/writing-observer/myenv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp313-cp313-macosx_10_13_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 35.9 MB/s eta 0:00:00m eta 0:00:01
# Downloading contourpy-1.3.1-cp313-cp313-macosx_10_13_x86_64.whl (271 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.8-cp313-cp313-macosx_10_13_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-macosx_10_13_x86_64.whl (66 kB)
# Downloading numpy-2.2.2-cp313-cp313-macosx_10_13_x86_64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 63.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pillow-11.1.0-cp313-cp313-macosx_10_13_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 38.4 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.8 kiwisolver-1.4.8 matplotlib-3.10.0 numpy-2.2.2 pillow-11.1.0 pyparsing-3.2.1

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = y = [1, 4, 9, 16, 25]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(x, y)

# Add title and labels
plt.title('Simple Plot')
plt.xlabel('X values')
plt.ylabel('Y values')

# Display the plot
plt.show()

# %%
print("hi")
# Out:
# hi

# %%
print([x for x in range(5)])
